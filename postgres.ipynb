# %%
import os
from dotenv import load_dotenv
import pandas as pd
from sqlalchemy import create_engine, text, inspect

# %% [markdown]
# Load in the CSV data file to convert it to Postgres Table

# %%
## run --name is for new containers
# docker run --name my-postgres \
#   -e POSTGRES_USER=postgresuser \
#   -e POSTGRES_PASSWORD=postgressql \
#   -e POSTGRES_DB=movies \
#   -p 5432:5432 \
#   -d postgres:14

# %%
# file path
csv_path = 'data/actor-films.csv'

df = pd.read_csv(csv_path)
print(f"Loaded {len(df)} rows from CSV.")
# Out:
# Loaded 169770 rows from CSV.

# %%
def query_sql(sql_engine, sql_statement):
     """Executes standard sql query with sql alchemy engine and sql command"""
     return pd.read_sql_query(sql_statement, sql_engine)

def execute_sql(sql_engine, sql_statement):
    """Executes sql action with sql alchemy engine and sql command"""
    with sql_engine.connect() as conn:
        result = conn.execute(text(sql_statement))
        if conn.commit():
            print("Executions Succesful")

def inspect_database(sql_engine):
    """Inspects and prints active table names"""
    database_inspector = inspect(sql_engine)
    tables = database_inspector.get_table_names()
    print("Tables in the database:", tables)

# %%
# Load .env file and get username and password
load_dotenv()

DB_USER = os.getenv("DB_USER")
DB_PASSWORD = os.getenv("DB_PASSWORD")
DB_HOST = os.getenv("DB_HOST")
DB_PORT = os.getenv("DB_PORT")
DB_NAME = os.getenv("DB_NAME")

# %%
# Postgres connection details
username = DB_USER
password = DB_PASSWORD
host = DB_HOST
port = DB_PORT
database = DB_NAME

# Create the SQLalchemy engine
engine = create_engine(f'postgresql://{username}:{password}@{host}:{port}/{database}')

# Test connection
with engine.connect() as conn:
    result = conn.execute(text("SELECT version();"))
    version = result.fetchone()
    print("Connected to:", version[0])
# Out:
# Connected to: PostgreSQL 14.15 (Debian 14.15-1.pgdg120+1) on x86_64-pc-linux-gnu, compiled by gcc (Debian 12.2.0-14) 12.2.0, 64-bit

# %%
inspect_database(engine)
# Out:
# Tables in the database: ['actor_films', 'actors']

# %%
# Drop table and types if they already exist
drop_data="""
DROP TABLE IF EXISTS actor_films;
DROP TABLE IF EXISTS actors;
DROP TYPE IF EXISTS films;
DROP TYPE IF EXISTS quality_class;
"""
execute_sql(engine, drop_data)

# %%
inspect_database(engine)
# Out:
# Tables in the database: []

# %%
# Write DataFrame to Postgres table named 'actor_films'
df.to_sql('actor_films', engine, if_exists='replace', index=False)
print("Data loaded into Postgres successfully!")
# Out:
# Data loaded into Postgres successfully!

# %%
# Query back data from Postgres
result = pd.read_sql_query("SELECT * FROM actor_films LIMIT 5;", engine)
result
# Out:
#            actor    actorid                   film  year  votes  rating  \
# 0   Fred Astaire  nm0000001            Ghost Story  1981   7731     6.3
# 1   Fred Astaire  nm0000001        The Purple Taxi  1977    533     6.6
# 2   Fred Astaire  nm0000001  The Amazing Dobermans  1976    369     5.3
# 3   Fred Astaire  nm0000001   The Towering Inferno  1974  39888     7.0
# 4  Lauren Bacall  nm0000002     Ernest & Celestine  2012  18793     7.9
#
#       filmid
# 0  tt0082449
# 1  tt0076851
# 2  tt0074130
# 3  tt0072308
# 4  tt1816518

# %%
query_sql(engine, "SELECT * FROM actor_films WHERE actor = 'Hugh Jackman';")
# Out:
#            actor    actorid                                     film  year  \
# 0   Hugh Jackman  nm0413168                            Bad Education  2019
# 1   Hugh Jackman  nm0413168                             Missing Link  2019
# 2   Hugh Jackman  nm0413168                         The Front Runner  2018
# 3   Hugh Jackman  nm0413168                                    Logan  2017
# 4   Hugh Jackman  nm0413168                     The Greatest Showman  2017
# 5   Hugh Jackman  nm0413168                        X-Men: Apocalypse  2016
# 6   Hugh Jackman  nm0413168                                  Chappie  2015
# 7   Hugh Jackman  nm0413168           Me and Earl and the Dying Girl  2015
# 8   Hugh Jackman  nm0413168                          Eddie the Eagle  2015
# 9   Hugh Jackman  nm0413168                                      Pan  2015
# 10  Hugh Jackman  nm0413168               X-Men: Days of Future Past  2014
# 11  Hugh Jackman  nm0413168  Night at the Museum: Secret of the Tomb  2014
# 12  Hugh Jackman  nm0413168                                Prisoners  2013
# 13  Hugh Jackman  nm0413168                            The Wolverine  2013
# 14  Hugh Jackman  nm0413168                                 Movie 43  2013
# 15  Hugh Jackman  nm0413168                           Les Miserables  2012
# 16  Hugh Jackman  nm0413168                    Rise of the Guardians  2012
# 17  Hugh Jackman  nm0413168                       X-Men: First Class  2011
# 18  Hugh Jackman  nm0413168                               Real Steel  2011
# 19  Hugh Jackman  nm0413168                                   Butter  2011
# 20  Hugh Jackman  nm0413168           Snow Flower and the Secret Fan  2011
# 21  Hugh Jackman  nm0413168                 X-Men Origins: Wolverine  2009
# 22  Hugh Jackman  nm0413168                                Australia  2008
# 23  Hugh Jackman  nm0413168                                Deception  2008
# 24  Hugh Jackman  nm0413168                             The Prestige  2006
# 25  Hugh Jackman  nm0413168                    X-Men: The Last Stand  2006
# 26  Hugh Jackman  nm0413168                             The Fountain  2006
# 27  Hugh Jackman  nm0413168                               Happy Feet  2006
# 28  Hugh Jackman  nm0413168                             Flushed Away  2006
# 29  Hugh Jackman  nm0413168                                    Scoop  2006
# 30  Hugh Jackman  nm0413168                              Van Helsing  2004
# 31  Hugh Jackman  nm0413168                                  X-Men 2  2003
# 32  Hugh Jackman  nm0413168                                Swordfish  2001
# 33  Hugh Jackman  nm0413168                           Kate & Leopold  2001
# 34  Hugh Jackman  nm0413168                      Someone Like You...  2001
# 35  Hugh Jackman  nm0413168                                    X-Men  2000
# 36  Hugh Jackman  nm0413168                           Paperback Hero  1999
# 37  Hugh Jackman  nm0413168                       Erskineville Kings  1999
#
#       votes  rating     filmid
# 0     33654     7.1  tt8206668
# 1     22582     6.7  tt6348138
# 2     11768     6.1  tt7074886
# 3    658088     8.1  tt3315342
# 4    243946     7.6  tt1485796
# 5    398093     6.9  tt3385516
# 6    231315     6.8  tt1823672
# 7    124443     7.7  tt2582496
# 8     86743     7.4  tt1083452
# 9     60912     5.7  tt3332064
# 10   665362     7.9  tt1877832
# 11   108627     6.2  tt2692250
# 12   610670     8.1  tt1392214
# 13   433413     6.7  tt1430132
# 14   100039     4.3  tt1333125
# 15   311317     7.6  tt1707386
# 16   158632     7.3  tt1446192
# 17   650154     7.7  tt1270798
# 18   299988     7.1  tt0433035
# 19    20601     6.2  tt1349451
# 20     3589     6.1  tt1541995
# 21   471190     6.6  tt0458525
# 22   119815     6.6  tt0455824
# 23    37894     6.1  tt0800240
# 24  1205150     8.5  tt0482571
# 25   486265     6.7  tt0376994
# 26   229813     7.2  tt0414993
# 27   171475     6.4  tt0366548
# 28   114687     6.6  tt0424095
# 29    81311     6.6  tt0457513
# 30   246540     6.1  tt0338526
# 31   515580     7.4  tt0290334
# 32   176924     6.5  tt0244244
# 33    79430     6.4  tt0035423
# 34    23635     6.1  tt0244970
# 35   575186     7.4  tt0120903
# 36     2041     6.5  tt0180037
# 37      497     6.5  tt0212936

# %%
create_sql = """
CREATE TYPE quality_class AS ENUM ('star', 'good', 'average', 'bad');

CREATE TYPE films AS (
    film TEXT,
    votes INTEGER,
    rating REAL,
    filmid TEXT
);

CREATE TABLE actors (
    actor TEXT,
    actorid TEXT,
    quality_class quality_class,
    is_active BOOL,
    current_year SMALLINT,
    films films[],
    PRIMARY KEY(actorid, current_year)
);
"""
execute_sql(engine, create_sql)

# %%
# %reload_ext sql
# %load_ext sql
# %config SqlMagic.style = 'SINGLE_BORDER'
# %sql postgresql://postgresuser:postgressql@localhost:5432/movies

# %%
# %config SqlMagic.style = '_DEPRECATED_PLAIN_COLUMNS'

# %%
# %%sql
#
# SELECT * FROM actor_films LIMIT 5;
# Out:
#  * postgresql://postgresuser:***@localhost:5432/movies
# 5 rows affected.
# [('Fred Astaire', 'nm0000001', 'Ghost Story', 1981, 7731, 6.3, 'tt0082449'),
#  ('Fred Astaire', 'nm0000001', 'The Purple Taxi', 1977, 533, 6.6, 'tt0076851'),
#  ('Fred Astaire', 'nm0000001', 'The Amazing Dobermans', 1976, 369, 5.3, 'tt0074130'),
#  ('Fred Astaire', 'nm0000001', 'The Towering Inferno', 1974, 39888, 7.0, 'tt0072308'),
#  ('Lauren Bacall', 'nm0000002', 'Ernest & Celestine', 2012, 18793, 7.9, 'tt1816518')]

# %%
import prettytable

print("Keys in prettytable.__dict__:")
for key in prettytable.__dict__.keys():
    print(key)

print("\nAvailable styles via dir(prettytable):")
# Filter for uppercase attributes that might be styles
for attr in dir(prettytable):
    if attr.isupper() and not attr.startswith('__'):
        print(attr)

print("\nValue of prettytable.DEFAULT:")
try:
    print(prettytable.DEFAULT)
except AttributeError:
    print("prettytable.DEFAULT is not directly accessible as an attribute.")
# Out:
# Keys in prettytable.__dict__:
# __name__
# __doc__
# __package__
# __loader__
# __spec__
# __path__
# __file__
# __cached__
# __builtins__
# annotations
# Any
# _version
# __version__
# prettytable
# _DEPRECATED_ALL
# _DEPRECATED_DEFAULT
# _DEPRECATED_DOUBLE_BORDER
# _DEPRECATED_FRAME
# _DEPRECATED_HEADER
# _DEPRECATED_MARKDOWN
# _DEPRECATED_MSWORD_FRIENDLY
# _DEPRECATED_NONE
# _DEPRECATED_ORGMODE
# _DEPRECATED_PLAIN_COLUMNS
# _DEPRECATED_RANDOM
# _DEPRECATED_SINGLE_BORDER
# HRuleStyle
# PrettyTable
# RowType
# TableHandler
# TableStyle
# VRuleStyle
# _warn_deprecation
# from_csv
# from_db_cursor
# from_html
# from_html_one
# from_json
# from_mediawiki
# __all__
# __getattr__
#
# Available styles via dir(prettytable):
# _DEPRECATED_ALL
# _DEPRECATED_DEFAULT
# _DEPRECATED_DOUBLE_BORDER
# _DEPRECATED_FRAME
# _DEPRECATED_HEADER
# _DEPRECATED_MARKDOWN
# _DEPRECATED_MSWORD_FRIENDLY
# _DEPRECATED_NONE
# _DEPRECATED_ORGMODE
# _DEPRECATED_PLAIN_COLUMNS
# _DEPRECATED_RANDOM
# _DEPRECATED_SINGLE_BORDER
#
# Value of prettytable.DEFAULT:
# 10
# /var/folders/n2/9mbm84vn1nggy8sn6c1bbtxm0000gn/T/ipykernel_11082/3783143175.py:15: DeprecationWarning: the 'DEFAULT' constant is deprecated, use the 'TableStyle' enum instead
#   print(prettytable.DEFAULT)

# %%
plpgsql_code = """
DO $$ 
DECLARE  
    start_year INT := 1969;  
    end_year INT := 2021;  
    current INT;  
BEGIN 
FOR current IN start_year..end_year-1 LOOP 
    INSERT INTO actors
    -- Your full CTE and SELECT block here --
    WITH previous_year AS (
        SELECT * FROM actors
        WHERE current_year = current
    ), 
    current_year AS (
        SELECT actor,
               actorid,
               ARRAY_AGG(
                   ARRAY[ROW(
                       film,
                       votes,
                       rating,
                       filmid
                   )::films] 
               ORDER BY rating DESC
               ) AS films,
               year AS current_year
        FROM actor_films
        WHERE year = current + 1
        GROUP BY actor, actorid, year
    ), 
    combined_years AS (
        SELECT COALESCE(cy.actor, py.actor) AS actor,
               COALESCE(cy.actorid, py.actorid) AS actorid,    
               CASE
                 WHEN cy.current_year IS NOT NULL THEN TRUE
                 ELSE FALSE
               END AS is_active,
               COALESCE(cy.current_year, py.current_year +1) AS current_year,
               CASE 
                 WHEN py.films IS NULL THEN cy.films
                 WHEN cy.current_year IS NOT NULL THEN py.films || cy.films
                 ELSE py.films
               END        
        FROM current_year as cy
        FULL OUTER JOIN previous_year as py
        ON cy.actorid = py.actorid
    )
    SELECT 
        cy.actor,
        cy.actorid,
        CASE 
            WHEN avg_rating > 8 THEN 'star'
            WHEN avg_rating > 7 THEN 'good'
            WHEN avg_rating > 6 THEN 'average'
            ELSE 'bad'
        END::quality_class AS quality_class,
        cy.is_active,
        cy.current_year,
        cy.films
    FROM (
        SELECT 
            actor,
            actorid,
            is_active,
            current_year,
            films,
            (SELECT AVG((f).rating) 
             FROM unnest(films) AS f) AS avg_rating
        FROM combined_years
    ) AS cy;
END LOOP;  
END $$;
"""

execute_sql(engine, plpgsql_code)

print("Actors table populated!")
# Out:
# Actors table populated!

# %%
query_sql(engine, "SELECT * FROM actors WHERE actor='Ralph Fiennes'")
# Out:
#             actor    actorid quality_class  is_active  current_year  \
# 0   Ralph Fiennes  nm0000146       average       True          1992
# 1   Ralph Fiennes  nm0000146          good       True          1996
# 2   Ralph Fiennes  nm0000146          good       True          1993
# 3   Ralph Fiennes  nm0000146          good       True          1995
# 4   Ralph Fiennes  nm0000146          good       True          1994
# 5   Ralph Fiennes  nm0000146       average       True          1998
# 6   Ralph Fiennes  nm0000146          good       True          1997
# 7   Ralph Fiennes  nm0000146       average       True          2007
# 8   Ralph Fiennes  nm0000146       average       True          2000
# 9   Ralph Fiennes  nm0000146       average       True          2002
# 10  Ralph Fiennes  nm0000146       average       True          1999
# 11  Ralph Fiennes  nm0000146       average      False          2001
# 12  Ralph Fiennes  nm0000146       average      False          2003
# 13  Ralph Fiennes  nm0000146       average      False          2004
# 14  Ralph Fiennes  nm0000146       average       True          2005
# 15  Ralph Fiennes  nm0000146       average       True          2006
# 16  Ralph Fiennes  nm0000146       average      False          2009
# 17  Ralph Fiennes  nm0000146       average       True          2008
# 18  Ralph Fiennes  nm0000146       average       True          2012
# 19  Ralph Fiennes  nm0000146       average       True          2010
# 20  Ralph Fiennes  nm0000146       average       True          2011
# 21  Ralph Fiennes  nm0000146       average       True          2013
# 22  Ralph Fiennes  nm0000146       average       True          2014
# 23  Ralph Fiennes  nm0000146       average       True          2015
# 24  Ralph Fiennes  nm0000146       average       True          2016
# 25  Ralph Fiennes  nm0000146       average       True          2017
# 26  Ralph Fiennes  nm0000146       average       True          2018
# 27  Ralph Fiennes  nm0000146       average       True          2019
# 28  Ralph Fiennes  nm0000146       average       True          2020
# 29  Ralph Fiennes  nm0000146       average       True          2021
#
#                                                 films
# 0   {{"(\"Wuthering Heights\",12384,6.8,tt0104181)"}}
# 1   {{"(\"Wuthering Heights\",12384,6.8,tt0104181)...
# 2   {{"(\"Wuthering Heights\",12384,6.8,tt0104181)...
# 3   {{"(\"Wuthering Heights\",12384,6.8,tt0104181)...
# 4   {{"(\"Wuthering Heights\",12384,6.8,tt0104181)...
# 5   {{"(\"Wuthering Heights\",12384,6.8,tt0104181)...
# 6   {{"(\"Wuthering Heights\",12384,6.8,tt0104181)...
# 7   {{"(\"Wuthering Heights\",12384,6.8,tt0104181)...
# 8   {{"(\"Wuthering Heights\",12384,6.8,tt0104181)...
# 9   {{"(\"Wuthering Heights\",12384,6.8,tt0104181)...
# 10  {{"(\"Wuthering Heights\",12384,6.8,tt0104181)...
# 11  {{"(\"Wuthering Heights\",12384,6.8,tt0104181)...
# 12  {{"(\"Wuthering Heights\",12384,6.8,tt0104181)...
# 13  {{"(\"Wuthering Heights\",12384,6.8,tt0104181)...
# 14  {{"(\"Wuthering Heights\",12384,6.8,tt0104181)...
# 15  {{"(\"Wuthering Heights\",12384,6.8,tt0104181)...
# 16  {{"(\"Wuthering Heights\",12384,6.8,tt0104181)...
# 17  {{"(\"Wuthering Heights\",12384,6.8,tt0104181)...
# 18  {{"(\"Wuthering Heights\",12384,6.8,tt0104181)...
# 19  {{"(\"Wuthering Heights\",12384,6.8,tt0104181)...
# 20  {{"(\"Wuthering Heights\",12384,6.8,tt0104181)...
# 21  {{"(\"Wuthering Heights\",12384,6.8,tt0104181)...
# 22  {{"(\"Wuthering Heights\",12384,6.8,tt0104181)...
# 23  {{"(\"Wuthering Heights\",12384,6.8,tt0104181)...
# 24  {{"(\"Wuthering Heights\",12384,6.8,tt0104181)...
# 25  {{"(\"Wuthering Heights\",12384,6.8,tt0104181)...
# 26  {{"(\"Wuthering Heights\",12384,6.8,tt0104181)...
# 27  {{"(\"Wuthering Heights\",12384,6.8,tt0104181)...
# 28  {{"(\"Wuthering Heights\",12384,6.8,tt0104181)...
# 29  {{"(\"Wuthering Heights\",12384,6.8,tt0104181)...

# %%
# %%sql
#
# CREATE TYPE quality_class AS ENUM ('star', 'good', 'average', 'bad');
#
# CREATE TYPE films AS (
#     film TEXT,
#     votes INTEGER,
#     rating REAL,
#     filmid TEXT
# );
#
# CREATE TABLE actors (
#     actor TEXT,
#     actorid TEXT,
#     quality_class quality_class,
#     is_active BOOL,
#     current_year SMALLINT,
#     films films[],
#     PRIMARY KEY(actorid, current_year)
# );
# Out:
#  * postgresql://postgresuser:***@localhost:5432/movies
# Done.
# Done.
# Done.
# []

# %%
# %%sql
#
# DO $$
# DECLARE
#     start_year INT := 1969;
#     end_year INT := 2021;
#     current INT;
# BEGIN
# FOR current IN start_year..end_year-1 LOOP
#     INSERT INTO actors
#     -- Your full CTE and SELECT block here --
#     WITH previous_year AS (
#         SELECT * FROM actors
#         WHERE current_year = current
#     ),
#     current_year AS (
#         SELECT actor,
#                actorid,
#                ARRAY_AGG(
#                    ARRAY[ROW(
#                        film,
#                        votes,
#                        rating,
#                        filmid
#                    )::films]
#                ORDER BY rating DESC
#                ) AS films,
#                year AS current_year
#         FROM actor_films
#         WHERE year = current + 1
#         GROUP BY actor, actorid, year
#     ),
#     combined_years AS (
#         SELECT COALESCE(cy.actor, py.actor) AS actor,
#                COALESCE(cy.actorid, py.actorid) AS actorid,
#                CASE
#                  WHEN cy.current_year IS NOT NULL THEN TRUE
#                  ELSE FALSE
#                END AS is_active,
#                COALESCE(cy.current_year, py.current_year +1) AS current_year,
#                CASE
#                  WHEN py.films IS NULL THEN cy.films
#                  WHEN cy.current_year IS NOT NULL THEN py.films || cy.films
#                  ELSE py.films
#                END
#         FROM current_year as cy
#         FULL OUTER JOIN previous_year as py
#         ON cy.actorid = py.actorid
#     )
#     SELECT
#         cy.actor,
#         cy.actorid,
#         CASE
#             WHEN avg_rating > 8 THEN 'star'
#             WHEN avg_rating > 7 THEN 'good'
#             WHEN avg_rating > 6 THEN 'average'
#             ELSE 'bad'
#         END::quality_class AS quality_class,
#         cy.is_active,
#         cy.current_year,
#         cy.films
#     FROM (
#         SELECT
#             actor,
#             actorid,
#             is_active,
#             current_year,
#             films,
#             (SELECT AVG((f).rating)
#              FROM unnest(films) AS f) AS avg_rating
#         FROM combined_years
#     ) AS cy;
# END LOOP;
# END $$;
# Out:
#  * postgresql://postgresuser:***@localhost:5432/movies
# Done.
# []

# %%
# %%sql
#
# SELECT * FROM actors WHERE actor = 'Hugh Jackman' LIMIT 5;
# Out:
#  * postgresql://postgresuser:***@localhost:5432/movies
# 5 rows affected.
# [('Hugh Jackman', 'nm0413168', 'average', True, 1999, '{{"(\\"Paperback Hero\\",2041,6.5,tt0180037)"},{"(\\"Erskineville Kings\\",497,6.5,tt0212936)"}}'),
#  ('Hugh Jackman', 'nm0413168', 'average', True, 2000, '{{"(\\"Paperback Hero\\",2041,6.5,tt0180037)"},{"(\\"Erskineville Kings\\",497,6.5,tt0212936)"},{"(X-Men,575186,7.4,tt0120903)"}}'),
#  ('Hugh Jackman', 'nm0413168', 'average', True, 2001, '{{"(\\"Paperback Hero\\",2041,6.5,tt0180037)"},{"(\\"Erskineville Kings\\",497,6.5,tt0212936)"},{"(X-Men,575186,7.4,tt0120903)"},{"(Swordfish,176924,6.5,tt0244244)"},{"(\\"Kate & Leopold\\",79430,6.4,tt0035423)"},{"(\\"Someone Like You...\\",23635,6.1,tt0244970)"}}'),
#  ('Hugh Jackman', 'nm0413168', 'average', False, 2002, '{{"(\\"Paperback Hero\\",2041,6.5,tt0180037)"},{"(\\"Erskineville Kings\\",497,6.5,tt0212936)"},{"(X-Men,575186,7.4,tt0120903)"},{"(Swordfish,176924,6.5,tt0244244)"},{"(\\"Kate & Leopold\\",79430,6.4,tt0035423)"},{"(\\"Someone Like You...\\",23635,6.1,tt0244970)"}}'),
#  ('Hugh Jackman', 'nm0413168', 'average', True, 2003, '{{"(\\"Paperback Hero\\",2041,6.5,tt0180037)"},{"(\\"Erskineville Kings\\",497,6.5,tt0212936)"},{"(X-Men,575186,7.4,tt0120903)"},{"(Swordfish,176924, ... (8 characters truncated) ... 44244)"},{"(\\"Kate & Leopold\\",79430,6.4,tt0035423)"},{"(\\"Someone Like You...\\",23635,6.1,tt0244970)"},{"(\\"X-Men 2\\",515580,7.4,tt0290334)"}}')]

# %%
# %%sql
# WITH get_actor AS (
#     SELECT actor, quality_class, is_active,
#        UNNEST(films) AS movies
#     FROM actors
#     WHERE actor = 'Hugh Jackman' AND current_year = 2012
# )
#
# SELECT actor, quality_class, is_active,
#      (movies::films).film as film,
#      (movies::films).rating as rating
#
# FROM get_actor;
# Out:
#  * postgresql://postgresuser:***@localhost:5432/movies
# 23 rows affected.
# [('Hugh Jackman', 'average', True, 'Paperback Hero', 6.5),
#  ('Hugh Jackman', 'average', True, 'Erskineville Kings', 6.5),
#  ('Hugh Jackman', 'average', True, 'X-Men', 7.4),
#  ('Hugh Jackman', 'average', True, 'Swordfish', 6.5),
#  ('Hugh Jackman', 'average', True, 'Kate & Leopold', 6.4),
#  ('Hugh Jackman', 'average', True, 'Someone Like You...', 6.1),
#  ('Hugh Jackman', 'average', True, 'X-Men 2', 7.4),
#  ('Hugh Jackman', 'average', True, 'Van Helsing', 6.1),
#  ('Hugh Jackman', 'average', True, 'The Prestige', 8.5),
#  ('Hugh Jackman', 'average', True, 'The Fountain', 7.2),
#  ('Hugh Jackman', 'average', True, 'X-Men: The Last Stand', 6.7),
#  ('Hugh Jackman', 'average', True, 'Flushed Away', 6.6),
#  ('Hugh Jackman', 'average', True, 'Scoop', 6.6),
#  ('Hugh Jackman', 'average', True, 'Happy Feet', 6.4),
#  ('Hugh Jackman', 'average', True, 'Australia', 6.6),
#  ('Hugh Jackman', 'average', True, 'Deception', 6.1),
#  ('Hugh Jackman', 'average', True, 'X-Men Origins: Wolverine', 6.6),
#  ('Hugh Jackman', 'average', True, 'X-Men: First Class', 7.7),
#  ('Hugh Jackman', 'average', True, 'Real Steel', 7.1),
#  ('Hugh Jackman', 'average', True, 'Butter', 6.2),
#  ('Hugh Jackman', 'average', True, 'Snow Flower and the Secret Fan', 6.1),
#  ('Hugh Jackman', 'average', True, 'Les Miserables', 7.6),
#  ('Hugh Jackman', 'average', True, 'Rise of the Guardians', 7.3)]

# %%
query_sql(engine, "SELECT actor, quality_class, is_active, UNNEST(films) AS movies FROM actors WHERE actor = 'Hugh Jackman' AND current_year = 2012;")
# Out:
#            actor quality_class  is_active  \
# 0   Hugh Jackman       average       True
# 1   Hugh Jackman       average       True
# 2   Hugh Jackman       average       True
# 3   Hugh Jackman       average       True
# 4   Hugh Jackman       average       True
# 5   Hugh Jackman       average       True
# 6   Hugh Jackman       average       True
# 7   Hugh Jackman       average       True
# 8   Hugh Jackman       average       True
# 9   Hugh Jackman       average       True
# 10  Hugh Jackman       average       True
# 11  Hugh Jackman       average       True
# 12  Hugh Jackman       average       True
# 13  Hugh Jackman       average       True
# 14  Hugh Jackman       average       True
# 15  Hugh Jackman       average       True
# 16  Hugh Jackman       average       True
# 17  Hugh Jackman       average       True
# 18  Hugh Jackman       average       True
# 19  Hugh Jackman       average       True
# 20  Hugh Jackman       average       True
# 21  Hugh Jackman       average       True
# 22  Hugh Jackman       average       True
#
#                                                movies
# 0               ("Paperback Hero",2041,6.5,tt0180037)
# 1            ("Erskineville Kings",497,6.5,tt0212936)
# 2                        (X-Men,575186,7.4,tt0120903)
# 3                    (Swordfish,176924,6.5,tt0244244)
# 4              ("Kate & Leopold",79430,6.4,tt0035423)
# 5         ("Someone Like You...",23635,6.1,tt0244970)
# 6                    ("X-Men 2",515580,7.4,tt0290334)
# 7                ("Van Helsing",246540,6.1,tt0338526)
# 8              ("The Prestige",1205150,8.5,tt0482571)
# 9               ("The Fountain",229813,7.2,tt0414993)
# 10     ("X-Men: The Last Stand",486265,6.7,tt0376994)
# 11              ("Flushed Away",114687,6.6,tt0424095)
# 12                        (Scoop,81311,6.6,tt0457513)
# 13                ("Happy Feet",171475,6.4,tt0366548)
# 14                   (Australia,119815,6.6,tt0455824)
# 15                    (Deception,37894,6.1,tt0800240)
# 16  ("X-Men Origins: Wolverine",471190,6.6,tt0458525)
# 17        ("X-Men: First Class",650154,7.7,tt1270798)
# 18                ("Real Steel",299988,7.1,tt0433035)
# 19                       (Butter,20601,6.2,tt1349451)
# 20  ("Snow Flower and the Secret Fan",3589,6.1,tt1...
# 21            ("Les Miserables",311317,7.6,tt1707386)
# 22     ("Rise of the Guardians",158632,7.3,tt1446192)
